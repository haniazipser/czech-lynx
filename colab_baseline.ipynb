# %%
# !git clone https://github.com/haniazipser/czech-lynx.git
# %cd czech-lynx

# !pip install -r requirements.txt -q
# !pip install -r requirements-torch.txt -q

# %%
from google.colab import files
files.upload()

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d picekl/czechlynx -p data/kaggle-data --unzip

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/czechlynx/checkpoints

# %%
import sys
sys.path.insert(0, '/content/czech-lynx')

# Override paths
from config.presets.baseline import get_config
cfg = get_config()
cfg.data_root = "/content/czech-lynx/data/kaggle-data"
cfg.csv_path  = "/content/czech-lynx/data/kaggle-data/CzechLynxDataset-Metadata-Real.csv"

# %%
# !python run_baseline.py \
  --data-root /content/czech-lynx/data/kaggle-data \
  --checkpoint-dir /content/drive/MyDrive/czechlynx/checkpoints
