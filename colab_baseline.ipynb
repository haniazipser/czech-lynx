# %%
import os

if not os.path.exists('/content/czech-lynx'):
    # !git clone https://github.com/haniazipser/czech-lynx.git
    
# %cd /content/czech-lynx
# !git checkout collab
# !git pull origin collab #temp
# !cat requirements.txt
# !pip install -r requirements.txt -q

# %%
from google.colab import files
files.upload()

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

import os
os.environ["KAGGLE_CACHE_DIR"] = "/content/kaggle_cache"

# !kaggle datasets download -d picekl/czechlynx -p /content/czech-lynx/data/kaggle-data --unzip

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/czechlynx/checkpoints

# %%
import wandb
wandb.login()

# %%
# !python run_baseline.py \
  --data-root /content/czech-lynx/data/kaggle-data \
  --csv-path /content/czech-lynx/data/kaggle-data/CzechLynxDataset-Metadata-Real.csv \
  --checkpoint-dir /content/drive/MyDrive/czechlynx/run
